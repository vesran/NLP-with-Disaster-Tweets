# %% [markdown]
# # MLP classification

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import f1_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score, accuracy_score

from src.utils.viz import *

# %%
# Read & split train test
filename = './data/clean_entire_corpus.csv'
df = pd.read_csv(filename)
df_train = df[df['source'] == 'train'].copy()
df_test = df[df['source'] == 'test'].copy()

# %% [markdown]
# ## Data preprocessing

# %%
# Encoding
def get_vocabulary(iter_sents):
    vocab = set()
    max_length = 0
    for text in iter_sents:
        tokens = text.split(' ')
        if len(tokens) > max_length:
            max_length = len(tokens)
        vocab.update(tokens)
    return vocab, max_length

vocab, max_length = get_vocabulary(df_train['clean_text'])

tokenizer = tf.keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(df_train['clean_text'])
sequences_train = tokenizer.texts_to_sequences(df_train['clean_text'])
sequences_test = tokenizer.texts_to_sequences(df_test['clean_text'])

# %%
# Padding
padded_seqs_train = tf.keras.preprocessing.sequence.pad_sequences(sequences_train, maxlen=max_length,
                                                            padding='post', truncating='post')
padded_seqs_test = tf.keras.preprocessing.sequence.pad_sequences(sequences_test, maxlen=max_length,
                                                            padding='post', truncating='post')

# %%
# Data sets
X_train = padded_seqs_train
X_test = padded_seqs_test
y_train = df_train['target'].values
y_test = df_test['target'].values

train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(1000).batch(100)
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(100)

# %%
# Build an index for embeddings
embeddings_index = {}
EMBEDDINGS_PATH = '/datascience/embeddings'
EMBEDDINGS_LENGTH = 50
print('Reading lines')
with open(os.path.join(EMBEDDINGS_PATH, 'glove.6B.50d.txt'), encoding='utf-8') as f:
    lines = f.readlines()

print('Extract embeddings')
for line in lines:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs

print('Create embeddings matrix')
word_index = tokenizer.word_index
embedding_matrix = np.zeros((len(word_index) + 1, EMBEDDINGS_LENGTH))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector
# Out:
# Reading lines
# Extract embeddings
# Create embeddings matrix

# %% [markdown]
# ## Training model

# %%
model = tf.keras.Sequential()
model.add(a := tf.keras.layers.Embedding(input_dim=len(word_index)+1, output_dim=EMBEDDINGS_LENGTH,
                                         input_length=max_length, weights=[embedding_matrix], trainable=False))
model.add(b := tf.keras.layers.Conv1D(filters=200, kernel_size=3))
model.add(c := tf.keras.layers.MaxPool1D())
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(64, activation='relu'))
model.add(h := tf.keras.layers.Dense(1, activation='sigmoid'))

optimizer = tf.keras.optimizers.Adam(learning_rate=0.00001)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['acc'])

EPOCHS = 80
history = model.fit(train_ds, epochs=EPOCHS, validation_data=test_ds)
# Out:
# Epoch 1/80
# 69/69 [==============================] - 2s 28ms/step - loss: 0.6759 - acc: 0.5803 - val_loss: 0.6660 - val_acc: 0.6044
# Epoch 2/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.6430 - acc: 0.6516 - val_loss: 0.6380 - val_acc: 0.6614
# Epoch 3/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.6151 - acc: 0.6982 - val_loss: 0.6127 - val_acc: 0.7067
# Epoch 4/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.5898 - acc: 0.7307 - val_loss: 0.5900 - val_acc: 0.7263
# Epoch 5/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.5675 - acc: 0.7493 - val_loss: 0.5711 - val_acc: 0.7337
# Epoch 6/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.5476 - acc: 0.7598 - val_loss: 0.5543 - val_acc: 0.7453
# Epoch 7/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.5316 - acc: 0.7686 - val_loss: 0.5417 - val_acc: 0.7518
# Epoch 8/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.5190 - acc: 0.7724 - val_loss: 0.5320 - val_acc: 0.7539
# Epoch 9/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.5083 - acc: 0.7762 - val_loss: 0.5242 - val_acc: 0.7567
# Epoch 10/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4996 - acc: 0.7794 - val_loss: 0.5179 - val_acc: 0.7576
# Epoch 11/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.4928 - acc: 0.7822 - val_loss: 0.5128 - val_acc: 0.7600
# Epoch 12/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.4861 - acc: 0.7844 - val_loss: 0.5085 - val_acc: 0.7637
# Epoch 13/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.4805 - acc: 0.7851 - val_loss: 0.5047 - val_acc: 0.7652
# Epoch 14/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4750 - acc: 0.7886 - val_loss: 0.5006 - val_acc: 0.7683
# Epoch 15/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.4704 - acc: 0.7912 - val_loss: 0.4974 - val_acc: 0.7702
# Epoch 16/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.4658 - acc: 0.7936 - val_loss: 0.4947 - val_acc: 0.7735
# Epoch 17/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.4621 - acc: 0.7942 - val_loss: 0.4919 - val_acc: 0.7729
# Epoch 18/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.4585 - acc: 0.7961 - val_loss: 0.4894 - val_acc: 0.7760
# Epoch 19/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.4547 - acc: 0.7981 - val_loss: 0.4872 - val_acc: 0.7751
# Epoch 20/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.4516 - acc: 0.7993 - val_loss: 0.4853 - val_acc: 0.7747
# Epoch 21/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4487 - acc: 0.8007 - val_loss: 0.4833 - val_acc: 0.7772
# Epoch 22/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.4460 - acc: 0.8016 - val_loss: 0.4821 - val_acc: 0.7793
# Epoch 23/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.4429 - acc: 0.8025 - val_loss: 0.4801 - val_acc: 0.7790
# Epoch 24/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.4405 - acc: 0.8044 - val_loss: 0.4787 - val_acc: 0.7815
# Epoch 25/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4385 - acc: 0.8058 - val_loss: 0.4780 - val_acc: 0.7809
# Epoch 26/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4363 - acc: 0.8083 - val_loss: 0.4762 - val_acc: 0.7793
# Epoch 27/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4338 - acc: 0.8094 - val_loss: 0.4751 - val_acc: 0.7815
# Epoch 28/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.4318 - acc: 0.8089 - val_loss: 0.4742 - val_acc: 0.7812
# Epoch 29/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.4299 - acc: 0.8113 - val_loss: 0.4736 - val_acc: 0.7809
# Epoch 30/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4283 - acc: 0.8101 - val_loss: 0.4726 - val_acc: 0.7821
# Epoch 31/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4262 - acc: 0.8130 - val_loss: 0.4717 - val_acc: 0.7827
# Epoch 32/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4246 - acc: 0.8121 - val_loss: 0.4711 - val_acc: 0.7846
# Epoch 33/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.4227 - acc: 0.8142 - val_loss: 0.4703 - val_acc: 0.7839
# Epoch 34/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.4212 - acc: 0.8161 - val_loss: 0.4697 - val_acc: 0.7833
# Epoch 35/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4199 - acc: 0.8151 - val_loss: 0.4692 - val_acc: 0.7867
# Epoch 36/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4181 - acc: 0.8192 - val_loss: 0.4686 - val_acc: 0.7855
# Epoch 37/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.4167 - acc: 0.8187 - val_loss: 0.4681 - val_acc: 0.7873
# Epoch 38/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4155 - acc: 0.8186 - val_loss: 0.4683 - val_acc: 0.7885
# Epoch 39/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4138 - acc: 0.8200 - val_loss: 0.4673 - val_acc: 0.7888
# Epoch 40/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4127 - acc: 0.8203 - val_loss: 0.4670 - val_acc: 0.7882
# Epoch 41/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.4111 - acc: 0.8235 - val_loss: 0.4665 - val_acc: 0.7879
# Epoch 42/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4097 - acc: 0.8225 - val_loss: 0.4665 - val_acc: 0.7882
# Epoch 43/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4085 - acc: 0.8227 - val_loss: 0.4672 - val_acc: 0.7907
# Epoch 44/80
# 69/69 [==============================] - 2s 26ms/step - loss: 0.4074 - acc: 0.8228 - val_loss: 0.4657 - val_acc: 0.7873
# Epoch 45/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4063 - acc: 0.8232 - val_loss: 0.4656 - val_acc: 0.7904
# Epoch 46/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4050 - acc: 0.8237 - val_loss: 0.4650 - val_acc: 0.7876
# Epoch 47/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4039 - acc: 0.8231 - val_loss: 0.4653 - val_acc: 0.7916
# Epoch 48/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.4025 - acc: 0.8256 - val_loss: 0.4649 - val_acc: 0.7895
# Epoch 49/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4014 - acc: 0.8257 - val_loss: 0.4645 - val_acc: 0.7879
# Epoch 50/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.4004 - acc: 0.8256 - val_loss: 0.4643 - val_acc: 0.7873
# Epoch 51/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.3991 - acc: 0.8257 - val_loss: 0.4641 - val_acc: 0.7879
# Epoch 52/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.3983 - acc: 0.8273 - val_loss: 0.4639 - val_acc: 0.7879
# Epoch 53/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.3970 - acc: 0.8275 - val_loss: 0.4639 - val_acc: 0.7882
# Epoch 54/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.3959 - acc: 0.8298 - val_loss: 0.4644 - val_acc: 0.7931
# Epoch 55/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.3948 - acc: 0.8285 - val_loss: 0.4637 - val_acc: 0.7888
# Epoch 56/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.3937 - acc: 0.8287 - val_loss: 0.4636 - val_acc: 0.7885
# Epoch 57/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.3925 - acc: 0.8300 - val_loss: 0.4640 - val_acc: 0.7931
# Epoch 58/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.3920 - acc: 0.8285 - val_loss: 0.4633 - val_acc: 0.7898
# Epoch 59/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.3907 - acc: 0.8295 - val_loss: 0.4633 - val_acc: 0.7913
# Epoch 60/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.3896 - acc: 0.8307 - val_loss: 0.4632 - val_acc: 0.7888
# Epoch 61/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.3888 - acc: 0.8313 - val_loss: 0.4632 - val_acc: 0.7910
# Epoch 62/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.3878 - acc: 0.8327 - val_loss: 0.4635 - val_acc: 0.7944
# Epoch 63/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.3865 - acc: 0.8329 - val_loss: 0.4633 - val_acc: 0.7922
# Epoch 64/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.3855 - acc: 0.8329 - val_loss: 0.4630 - val_acc: 0.7895
# Epoch 65/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.3846 - acc: 0.8332 - val_loss: 0.4633 - val_acc: 0.7922
# Epoch 66/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.3837 - acc: 0.8345 - val_loss: 0.4634 - val_acc: 0.7919
# Epoch 67/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.3829 - acc: 0.8338 - val_loss: 0.4630 - val_acc: 0.7895
# Epoch 68/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.3819 - acc: 0.8385 - val_loss: 0.4634 - val_acc: 0.7928
# Epoch 69/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.3809 - acc: 0.8361 - val_loss: 0.4631 - val_acc: 0.7907
# Epoch 70/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.3800 - acc: 0.8376 - val_loss: 0.4629 - val_acc: 0.7888
# Epoch 71/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.3789 - acc: 0.8376 - val_loss: 0.4639 - val_acc: 0.7968
# Epoch 72/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.3780 - acc: 0.8377 - val_loss: 0.4634 - val_acc: 0.7922
# Epoch 73/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.3769 - acc: 0.8383 - val_loss: 0.4628 - val_acc: 0.7895
# Epoch 74/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.3761 - acc: 0.8386 - val_loss: 0.4629 - val_acc: 0.7864
# Epoch 75/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.3750 - acc: 0.8399 - val_loss: 0.4629 - val_acc: 0.7882
# Epoch 76/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.3740 - acc: 0.8399 - val_loss: 0.4634 - val_acc: 0.7931
# Epoch 77/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.3731 - acc: 0.8411 - val_loss: 0.4628 - val_acc: 0.7888
# Epoch 78/80
# 69/69 [==============================] - 2s 24ms/step - loss: 0.3723 - acc: 0.8417 - val_loss: 0.4634 - val_acc: 0.7934
# Epoch 79/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.3714 - acc: 0.8408 - val_loss: 0.4630 - val_acc: 0.7892
# Epoch 80/80
# 69/69 [==============================] - 2s 25ms/step - loss: 0.3709 - acc: 0.8428 - val_loss: 0.4631 - val_acc: 0.7904

# %%
epochs = range(1, EPOCHS+1)
fig, axs = plt.subplots(1, 2, figsize=(25, 8))

axs[0].plot(epochs, history.history['acc'], color='blue', label='train')
axs[0].plot(epochs, history.history['val_acc'], color='orange', label='test')
axs[0].set_xticks(range(1, EPOCHS+1, 5))
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Accuracy')

axs[1].plot(epochs, history.history['loss'], color='blue', label='train')
axs[1].plot(epochs, history.history['val_loss'], color='orange', label='test')
axs[1].set_xticks(range(1, EPOCHS+1, 5))
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Loss')
plt.legend()

# %% [markdown]
# * The best score reaches 0.79 of accuracy

# %%
y_pred = model.predict(X_test).reshape(1, -1)[0]
y_pred = np.around(y_pred).astype(int)

plot_confusion_matrix(y_test, y_pred)
# Out:
# (<Figure size 432x432 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x294be6c9400>)

# %%
df_test['pred'] = y_pred
model_errors = df_test[df_test['pred'] != df_test['target']]
model_errors
# Out:
#           id   keyword                                               text  \
# 6861      70    ablaze  Burning Man Ablaze! by Turban Diva http://t.co...
# 6864      84    ablaze       SETTING MYSELF ABLAZE http://t.co/6vMe7P5XhC
# 6868      94    ablaze  @PhilippaEilhart @DhuBlath hurt but her eyes a...
# 6870     101  accident  Just got to love burning your self on a damn c...
# 6871     103  accident                    I hate badging shit in accident
# ...      ...       ...                                                ...
# 10087  10806   wrecked  RT CNBC '3 words from Disney CEO Bob Iger wrec...
# 10088  10807   wrecked  Smackdown tyme this should put me in a good mo...
# 10096  10857       NaN  To conference attendees! The blue line from th...
# 10098  10861       NaN  EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTE...
# 10101  10874       NaN  MEG issues Hazardous Weather Outlook (HWO) htt...
#
#        target source                                         clean_text  pred
# 6861        0   test             burning man ablaze by turban diva via      1
# 6864        0   test                             setting myself ablaze      1
# 6868        0   test      hurt but her eyes ablaze with insulted anger      1
# 6870        0   test  just got to love burning your self on a damn c...     1
# 6871        0   test                    i hate badging shit in accident     1
# ...       ...    ...                                                ...   ...
# 10087       1   test  rt cnbc words from disney ceo bob iger wrecked...     0
# 10088       0   test  smackdown tyme this should put me in a good mo...     1
# 10096       1   test  to conference attendees the blue line from the...     0
# 10098       0   test  earthquake safety los angeles safety fasteners...     1
# 10101       1   test          meg issues hazardous weather outlook how      0
#
# [711 rows x 7 columns]

# %%
top_unigrams = get_top_grams(model_errors['clean_text'], 20)
fig, ax = plt.subplots(1, 1, figsize=(18, 8))

df1 = pd.DataFrame(top_unigrams, columns = ['text' , 'count'])
df1['count'] = df1['count'].astype(float)
df1.plot(x='text', y='count', kind='bar', ax=ax, title='Unigram frequency')

# %%
top_bigrams = get_top_grams(model_errors['clean_text'], 20, gram=2)
fig, ax = plt.subplots(1, 1, figsize=(18, 8))

df1 = pd.DataFrame(top_bigrams, columns = ['text' , 'count'])
df1['count'] = df1['count'].astype(float)
df1.plot(x='text', y='count', kind='bar', ax=ax, title='Bigram frequency')

# %%
top_bigrams = get_top_grams(model_errors['clean_text'], 20, gram=3)
fig, ax = plt.subplots(1, 1, figsize=(18, 8))

df1 = pd.DataFrame(top_bigrams, columns = ['text' , 'count'])
df1['count'] = df1['count'].astype(float)
df1.plot(x='text', y='count', kind='bar', ax=ax, title='Trigram frequency')
